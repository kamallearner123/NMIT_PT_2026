# %%
# A Simple BST insertion

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


# Sample Tree
#
#         10
#        /  \
#       5    20
#      / \   / \
#     3   7 15 25
#


class Tree:
    def __init__(self):
        self.root=None

    def insert(self, n):
        new = Node(n)
        if self.root == None:
            self.root = new
            return
            
        temp = self.root
        
        while temp:
            if n < temp.data:
                if temp.left == None:
                    temp.left = new
                    return
                temp = temp.left
                
            else:
                if temp.right == None:
                    temp.right = new
                    return
                temp = temp.right

    def traverse(self, node=None):
        if node == None:
            node = self.root
        if node.left != None:
            self.traverse(node.left)
        print(node.data)
            
        if node.right != None:
            self.traverse(node.right)

    def get_depth(self, curr=None, depth=0):
        if 
        

t = Tree()
t.insert(10)
t.insert(11)

t.insert(12)
t.insert(13)
t.insert(1)
t.insert(0)

t.traverse()
# Out:
# 0
# 1
# 10
# 11
# 12
# 13

# %%
# Finding depth of the tree
